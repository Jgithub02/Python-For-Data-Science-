# %% [markdown]
# <a href="https://colab.research.google.com/github/Jgithub02/Python-For-Data-Science-/blob/main/session_1_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
# Method 1 Using Seperator
print("Data", "Science","Mentorship","Program","By","CampusX", sep = "-")

# Method 2 Using end
print("Data", end= "-")
print("Science",end= "-")
print("Mentorship",end= "-")
print("Program",end= "-")
print("By",end= "-")
print("CampusX")
# Use method 1 for less code and time saving.
# Out:
# Data-Science-Mentorship-Program-By-CampusX
# Data-Science-Mentorship-Program-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
celsius = float(input("enter temperature in celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# enter temperature in celsius: 77
# Temperature in Fahrenheit: 170.6

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a = int(input("enter first number: "))
b = int(input("enter second number: "))
temp = a
a=b
b = temp
print("after swapping")
print("first number: ", a)
print("second number: ", b)
# Out:
# enter first number: 23
# enter second number: 45
# after swapping
# first number:  45
# second number:  23

# %% [markdown]
# # Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
import math

# %%
# Write your code here

x1 = float(input("enter x1: "))
y1 = float(input("enter y1: "))
x2 = float(input("enter x2: "))
y2 = float(input("enter y2: "))


distance = math.sqrt((x2-x1)**2 +(y2-y1)**2)
print("distance between two coordinates is: ", distance)

# Method 2 without importing math library
distance_1 = ((x2-x1)**2 + (y2-y1)**2)**0.5
print("distance between two coordinates is: ", distance_1)
# Out:
# enter x1: 4
# enter y1: 6
# enter x2: 5
# enter y2: 10
# distance between two coordinates is:  4.123105625617661
# distance between two coordinates is:  4.123105625617661

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
Principle = int(input("enter principle amount: "))
RoI = float(input("enter rate of interest: "))
Time_period = int(input("enter time period: "))

Interest = Principle*RoI*Time_period/100
print("Simple Interest of ₹5000 at 15% rate of interest annually for 5 years is :  ", Interest)
# Out:
# enter principle amount: 5000
# enter rate of interest: 15
# enter time period: 5
# Simple Interest of ₹5000 at 15% rate of interest annually for 5 years is :   3750.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
